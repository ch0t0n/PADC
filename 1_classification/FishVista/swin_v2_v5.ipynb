# %% [markdown]
# Check the model names from Pytorch Computer Vision (Timm) library:

# %%
# Hyperparameters
MODEL = "swin_base_patch4_window7_224.ms_in1k_timm"
DEVICE_ID = 7
BATCH_SIZE = 128
IMAGE_SIZE = 224
EPOCHS = 100
LR = 1e-4
OPTIMIZER = "AdamW"
DATA_DIR = r'/home/c/choton/beemachine/datasets/Others/fish-vista'
LOG_DIR = f"./{MODEL}_logs/"
SEED = 42

# %%
# Pytorch vision package (Timm)
import timm

# List relevant models
timm_name = MODEL[:-5] # Removing _timm in the name
convnext_models = timm.list_models(f'{timm_name}*')
print(convnext_models)

pretrained_models = timm.list_models(f'{timm_name}*', pretrained=True)
print(pretrained_models)
# Out:
# []
# ['swin_base_patch4_window7_224.ms_in1k']

# %%
# Pytorch packages
import torch
from torch import nn
# from torch.nn import functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms

# Other packages
import os
import json
import random
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm
from sklearn.model_selection import train_test_split

# Seeding for consistant results
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
# Load the classification splits and check the shape
train_csv = os.path.join(DATA_DIR, r'classification_train.csv')
val_csv = os.path.join(DATA_DIR, r'classification_val.csv')
test_csv = os.path.join(DATA_DIR, r'classification_test.csv')
train_df = pd.read_csv(train_csv)
val_df = pd.read_csv(val_csv)
test_df = pd.read_csv(test_csv)

classes = sorted(train_df['standardized_species'].unique())
num_classes = len(classes)
class_to_idx = {cls: i for i, cls in enumerate(classes)}
print(f'Shape of FishVista classification datasets,  train: {train_df.shape}, validation: {val_df.shape}, test): {test_df.shape}')
print(f'Columns of the test dataset:', list(test_df.columns))
# Out:
# /tmp/ipykernel_1057506/3037820290.py:5: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv(train_csv)
# Shape of FishVista classification datasets,  train: (39800, 17), validation: (6779, 17), test): (9781, 17)
# Columns of the test dataset: ['filename', 'source_filename', 'original_format', 'arkid', 'family', 'source', 'owner', 'standardized_species', 'original_url', 'license', 'adipose_fin', 'pelvic_fin', 'barbel', 'multiple_dorsal_fin', 'file_name', 'verbatim_species', 'species']

# %%
class FishVistaDataset(Dataset):
    def __init__(self, dataframe, class_to_idx, transform=None):
        self.df = dataframe.reset_index(drop=True)
        self.transform = transform
        self.class_to_idx = class_to_idx

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_path = os.path.join(DATA_DIR, "Images", row["filename"])
        image = Image.open(img_path).convert("RGB")
        label = self.class_to_idx[row["standardized_species"]]
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
train_transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    # transforms.RandomHorizontalFlip(),
    # transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

val_transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

train_dataset = FishVistaDataset(train_df, class_to_idx, train_transform)
val_dataset = FishVistaDataset(val_df, class_to_idx, val_transform)
test_dataset = FishVistaDataset(test_df, class_to_idx, val_transform)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, persistent_workers=True, pin_memory=True)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4, persistent_workers=True, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4, persistent_workers=True, pin_memory=True)

print(f"Classes: {num_classes} | Train: {len(train_dataset)} | Val: {len(val_dataset)} | Test: {len(test_dataset)}")
# Out:
# Classes: 1758 | Train: 39800 | Val: 6779 | Test: 9781

# %%
image, label = train_dataset[33]
label
# Out:
# 768

# %%
# Get one batch from the train loader
iterr = iter(train_loader)
images, labels = next(iterr)

print("Batch image tensor shape:", images.shape)
print("Batch label tensor shape:", labels.shape)
# Out:
# Batch image tensor shape: torch.Size([128, 3, 224, 224])
# Batch label tensor shape: torch.Size([128])

# %%
# Loading the model
device = torch.device(f"cuda:{DEVICE_ID}")
num_classes = len(classes)
model = timm.create_model(timm_name, pretrained=True, num_classes=num_classes)
model.to(device)

# Setting up the criterion, optimizer and scheduler
criterion = nn.CrossEntropyLoss()  #label_smoothing=0.1)
if OPTIMIZER == "SGD":
    optimizer = torch.optim.SGD(
        model.parameters(), 
        lr=LR, 
        momentum=0.9, 
        weight_decay=1e-4)
elif OPTIMIZER == "AdamW":
    optimizer = torch.optim.AdamW(
        model.parameters(), 
        lr=LR, 
        weight_decay=1e-4)
else:
    optimizer = torch.optim.RMSprop(
        model.parameters(),
        lr=LR,       # typically around 0.256 / batch_size scaling, you can tune
        alpha=0.9,              # decay (smoothing constant)
        eps=0.001,              # numerical stability
        momentum=0.9,           # as in paper
        weight_decay=1e-5,      # L2 regularization
        centered=False          # same as paper’s setup
    )
scheduler = ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=2)

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss, correct, total = 0, 0, 0

    pbar = tqdm(train_loader, desc="[Train]", position=0, leave=False)
    for images, labels in pbar:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        _, preds = outputs.max(1)
        correct += preds.eq(labels).sum().item()
        total += labels.size(0)

        pbar.set_postfix(loss=loss.item())
    pbar.close()
    avg_loss = running_loss / total
    accuracy = correct / total
    return avg_loss, accuracy


def validate_one_epoch(model, val_loader, criterion, device):
    model.eval()
    running_loss, correct, total = 0, 0, 0

    with torch.no_grad():
        pbar = tqdm(val_loader, desc="[Val]", position=0, leave=False)
        for images, labels in pbar:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * images.size(0)
            _, preds = outputs.max(1)
            correct += preds.eq(labels).sum().item()
            total += labels.size(0)

            pbar.set_postfix(loss=loss.item())
    pbar.close()
    avg_loss = running_loss / total
    accuracy = correct / total
    return avg_loss, accuracy

def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler,
                device, epochs, log_dir):
    # Full training loop with logging and checkpointing 
    history = {"epoch": [], "train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
    checkpoints_dir = os.path.join(log_dir, "checkpoints")
    os.makedirs(checkpoints_dir, exist_ok=True)

    # Initialize validation loss and start training
    best_val_loss = float("inf")
    print("Starting the first epoch...")

    for epoch in range(epochs):
        # ---- Training ----
        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)

        # ---- Validation ----
        val_loss, val_acc = validate_one_epoch(model, val_loader, criterion, device)

        # ---- Scheduler ----
        scheduler.step(val_loss)

        # ---- Logging ----
        history["epoch"].append(epoch + 1)
        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["train_acc"].append(train_acc)
        history["val_acc"].append(val_acc)

        # ---- Checkpoint ----
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_path = os.path.join(checkpoints_dir, "best_model.pth")
            torch.save(model.state_dict(), best_path)

            checkpoint_path = os.path.join(checkpoints_dir, f"checkpoint_epoch{epoch+1}.pth")
            torch.save({
                "epoch": epoch + 1,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "val_loss": val_loss
            }, checkpoint_path)
        
        print(f"\r Epoch {epoch+1}/{EPOCHS} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")    
    print("Training complete!")

    # ---- Save logs ----
    df = pd.DataFrame(history)
    csv_logfile = os.path.join(log_dir, "training_log.csv")
    json_logfile = os.path.join(log_dir, "training_log.json")

    df.to_csv(csv_logfile, index=False)
    with open(json_logfile, "w") as f:
        json.dump(history, f, indent=4)

    return history

# %%
# %%time

history = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    device=device,
    epochs=EPOCHS,
    log_dir=LOG_DIR
)
# Out:
# Starting the first epoch...
#  Epoch 1/100 | Train Loss: 2.7036 | Train Acc: 0.5314 | Val Loss: 2.4411 | Val Acc: 0.5744
#  Epoch 2/100 | Train Loss: 1.1331 | Train Acc: 0.7777 | Val Loss: 1.6730 | Val Acc: 0.6721
#  Epoch 3/100 | Train Loss: 0.5675 | Train Acc: 0.8843 | Val Loss: 1.3230 | Val Acc: 0.7390
#  Epoch 4/100 | Train Loss: 0.2541 | Train Acc: 0.9532 | Val Loss: 1.1564 | Val Acc: 0.7767
#  Epoch 5/100 | Train Loss: 0.1136 | Train Acc: 0.9814 | Val Loss: 1.1079 | Val Acc: 0.7836
#  Epoch 6/100 | Train Loss: 0.0632 | Train Acc: 0.9899 | Val Loss: 1.1398 | Val Acc: 0.7759
#  Epoch 7/100 | Train Loss: 0.0668 | Train Acc: 0.9875 | Val Loss: 1.1244 | Val Acc: 0.7836
#  Epoch 8/100 | Train Loss: 0.0575 | Train Acc: 0.9889 | Val Loss: 1.1409 | Val Acc: 0.7901
#  Epoch 9/100 | Train Loss: 0.0192 | Train Acc: 0.9974 | Val Loss: 1.0416 | Val Acc: 0.8065
#  Epoch 10/100 | Train Loss: 0.0084 | Train Acc: 0.9995 | Val Loss: 1.0309 | Val Acc: 0.8081
#  Epoch 11/100 | Train Loss: 0.0060 | Train Acc: 0.9998 | Val Loss: 1.0346 | Val Acc: 0.8103
#  Epoch 12/100 | Train Loss: 0.0056 | Train Acc: 0.9997 | Val Loss: 1.0248 | Val Acc: 0.8152
#  Epoch 13/100 | Train Loss: 0.0060 | Train Acc: 0.9994 | Val Loss: 1.0836 | Val Acc: 0.8017
#  Epoch 14/100 | Train Loss: 0.0070 | Train Acc: 0.9993 | Val Loss: 1.0629 | Val Acc: 0.8106
#  Epoch 15/100 | Train Loss: 0.0065 | Train Acc: 0.9993 | Val Loss: 1.0914 | Val Acc: 0.8020
#  Epoch 16/100 | Train Loss: 0.0038 | Train Acc: 0.9998 | Val Loss: 1.0690 | Val Acc: 0.8112
#  Epoch 17/100 | Train Loss: 0.0048 | Train Acc: 0.9994 | Val Loss: 1.0876 | Val Acc: 0.8029
#  Epoch 18/100 | Train Loss: 0.0062 | Train Acc: 0.9990 | Val Loss: 1.0733 | Val Acc: 0.8078
#  Epoch 19/100 | Train Loss: 0.0040 | Train Acc: 0.9997 | Val Loss: 1.0498 | Val Acc: 0.8143
#  Epoch 20/100 | Train Loss: 0.0025 | Train Acc: 0.9999 | Val Loss: 1.0469 | Val Acc: 0.8141
#  Epoch 21/100 | Train Loss: 0.0022 | Train Acc: 0.9999 | Val Loss: 1.0503 | Val Acc: 0.8146
#  Epoch 22/100 | Train Loss: 0.0020 | Train Acc: 0.9999 | Val Loss: 1.0487 | Val Acc: 0.8147
#  Epoch 23/100 | Train Loss: 0.0021 | Train Acc: 0.9999 | Val Loss: 1.0496 | Val Acc: 0.8166
#  Epoch 24/100 | Train Loss: 0.0020 | Train Acc: 0.9998 | Val Loss: 1.0586 | Val Acc: 0.8144
#  Epoch 25/100 | Train Loss: 0.0017 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8149
#  Epoch 26/100 | Train Loss: 0.0015 | Train Acc: 1.0000 | Val Loss: 1.0503 | Val Acc: 0.8155
#  Epoch 27/100 | Train Loss: 0.0016 | Train Acc: 1.0000 | Val Loss: 1.0550 | Val Acc: 0.8156
#  Epoch 28/100 | Train Loss: 0.0016 | Train Acc: 0.9999 | Val Loss: 1.0531 | Val Acc: 0.8158
#  Epoch 29/100 | Train Loss: 0.0014 | Train Acc: 0.9999 | Val Loss: 1.0528 | Val Acc: 0.8162
#  Epoch 30/100 | Train Loss: 0.0017 | Train Acc: 0.9999 | Val Loss: 1.0524 | Val Acc: 0.8163
#  Epoch 31/100 | Train Loss: 0.0016 | Train Acc: 0.9999 | Val Loss: 1.0514 | Val Acc: 0.8165
#  Epoch 32/100 | Train Loss: 0.0015 | Train Acc: 0.9999 | Val Loss: 1.0535 | Val Acc: 0.8160
#  Epoch 33/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0513 | Val Acc: 0.8162
#  Epoch 34/100 | Train Loss: 0.0016 | Train Acc: 1.0000 | Val Loss: 1.0525 | Val Acc: 0.8165
#  Epoch 35/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8163
#  Epoch 36/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0520 | Val Acc: 0.8163
#  Epoch 37/100 | Train Loss: 0.0014 | Train Acc: 0.9999 | Val Loss: 1.0531 | Val Acc: 0.8159
#  Epoch 38/100 | Train Loss: 0.0015 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8158
#  Epoch 39/100 | Train Loss: 0.0014 | Train Acc: 0.9999 | Val Loss: 1.0534 | Val Acc: 0.8158
#  Epoch 40/100 | Train Loss: 0.0015 | Train Acc: 0.9999 | Val Loss: 1.0531 | Val Acc: 0.8160
#  Epoch 41/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8162
#  Epoch 42/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0529 | Val Acc: 0.8160
#  Epoch 43/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0528 | Val Acc: 0.8158
#  Epoch 44/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0529 | Val Acc: 0.8163
#  Epoch 45/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8162
#  Epoch 46/100 | Train Loss: 0.0015 | Train Acc: 0.9999 | Val Loss: 1.0529 | Val Acc: 0.8162
#  Epoch 47/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0529 | Val Acc: 0.8163
#  Epoch 48/100 | Train Loss: 0.0014 | Train Acc: 0.9999 | Val Loss: 1.0529 | Val Acc: 0.8163
#  Epoch 49/100 | Train Loss: 0.0015 | Train Acc: 0.9999 | Val Loss: 1.0530 | Val Acc: 0.8163
#  Epoch 50/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8163
#  Epoch 51/100 | Train Loss: 0.0015 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8163
#  Epoch 52/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8163
#  Epoch 53/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8163
#  Epoch 54/100 | Train Loss: 0.0015 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8163
#  Epoch 55/100 | Train Loss: 0.0015 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8163
#  Epoch 56/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8163
#  Epoch 57/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8163
#  Epoch 58/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8163
#  Epoch 59/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8163
#  Epoch 60/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0532 | Val Acc: 0.8163
#  Epoch 61/100 | Train Loss: 0.0014 | Train Acc: 0.9999 | Val Loss: 1.0531 | Val Acc: 0.8163
#  Epoch 62/100 | Train Loss: 0.0014 | Train Acc: 0.9999 | Val Loss: 1.0531 | Val Acc: 0.8163
#  Epoch 63/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8163
#  Epoch 64/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8163
#  Epoch 65/100 | Train Loss: 0.0014 | Train Acc: 0.9999 | Val Loss: 1.0530 | Val Acc: 0.8165
#  Epoch 66/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8163
#  Epoch 67/100 | Train Loss: 0.0014 | Train Acc: 0.9999 | Val Loss: 1.0530 | Val Acc: 0.8163
#  Epoch 68/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8163
#  Epoch 69/100 | Train Loss: 0.0016 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8165
#  Epoch 70/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8163
#  Epoch 71/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8165
#  Epoch 72/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8165
#  Epoch 73/100 | Train Loss: 0.0014 | Train Acc: 0.9999 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 74/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 75/100 | Train Loss: 0.0013 | Train Acc: 0.9999 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 76/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 77/100 | Train Loss: 0.0014 | Train Acc: 0.9999 | Val Loss: 1.0530 | Val Acc: 0.8165
#  Epoch 78/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8165
#  Epoch 79/100 | Train Loss: 0.0015 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 80/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 81/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 82/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0530 | Val Acc: 0.8165
#  Epoch 83/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 84/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 85/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 86/100 | Train Loss: 0.0015 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 87/100 | Train Loss: 0.0015 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 88/100 | Train Loss: 0.0015 | Train Acc: 1.0000 | Val Loss: 1.0532 | Val Acc: 0.8165
#  Epoch 89/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0532 | Val Acc: 0.8165
#  Epoch 90/100 | Train Loss: 0.0015 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 91/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 92/100 | Train Loss: 0.0013 | Train Acc: 0.9999 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 93/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0531 | Val Acc: 0.8165
#  Epoch 94/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0532 | Val Acc: 0.8165
#  Epoch 95/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0532 | Val Acc: 0.8165
#  Epoch 96/100 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 1.0533 | Val Acc: 0.8165
#  Epoch 97/100 | Train Loss: 0.0014 | Train Acc: 1.0000 | Val Loss: 1.0532 | Val Acc: 0.8165
#  Epoch 98/100 | Train Loss: 0.0014 | Train Acc: 0.9999 | Val Loss: 1.0532 | Val Acc: 0.8165
#  Epoch 99/100 | Train Loss: 0.0015 | Train Acc: 0.9999 | Val Loss: 1.0533 | Val Acc: 0.8165
#  Epoch 100/100 | Train Loss: 0.0015 | Train Acc: 1.0000 | Val Loss: 1.0533 | Val Acc: 0.8165
# Training complete!
# CPU times: user 4h 2min 6s, sys: 58min 12s, total: 5h 19s
# Wall time: 16h 19min 28s

# %%
test_loss, test_acc = validate_one_epoch(model, test_loader, criterion, device)
print(f"Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.4f}")
# Out:
# Test Loss: 0.9574 | Test Acc: 0.8275
