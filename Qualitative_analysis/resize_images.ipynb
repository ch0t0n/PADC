# %%
import os
from PIL import Image

def resize_images(input_folder, output_folder, base_size):
    # Create output directory if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            img_path = os.path.join(input_folder, filename)
            img = Image.open(img_path)

            # Resize using Lanczos (high-quality downsampling)
            resized_img = img.resize((base_size, base_size))
            
            # Save the result
            resized_img.save(os.path.join(output_folder, filename))
            print(f"Resized: {filename}")

# Usage
resize_images('bee_subplots', 'resized_bees', 224)
# Out:
# Resized: baseline_idx_550.png
# Resized: baseline_idx_760.png
# Resized: original_idx_101.png
# Resized: baseline_idx_101.png
# Resized: padc_idx_760.png
# Resized: original_idx_0.png
# Resized: padc_idx_440.png
# Resized: original_idx_440.png
# Resized: padc_idx_245.png
# Resized: original_idx_550.png
# Resized: original_idx_245.png
# Resized: padc_idx_550.png
# Resized: original_idx_760.png
# Resized: baseline_idx_0.png
# Resized: padc_idx_0.png
# Resized: baseline_idx_440.png
# Resized: padc_idx_101.png
# Resized: baseline_idx_245.png
